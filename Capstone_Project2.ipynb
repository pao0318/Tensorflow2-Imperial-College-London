# %% [markdown]
# <a href="https://colab.research.google.com/github/pao0318/Tensorflow2-Imperial-College-London/blob/main/Capstone_Project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Capstone Project
# ## Image classifier for the SVHN dataset
# ### Instructions
#
# In this notebook, you will create a neural network that classifies real-world images digits. You will use concepts from throughout this course in building, training, testing, validating and saving your Tensorflow classifier model.
#
# This project is peer-assessed. Within this notebook you will find instructions in each section for how to complete the project. Pay close attention to the instructions as the peer review will be carried out according to a grading rubric that checks key parts of the project instructions. Feel free to add extra cells into the notebook as required.
#
# ### How to submit
#
# When you have completed the Capstone project notebook, you will submit a pdf of the notebook for peer review. First ensure that the notebook has been fully executed from beginning to end, and all of the cell outputs are visible. This is important, as the grading rubric depends on the reviewer being able to view the outputs of your notebook. Save the notebook as a pdf (you could download the notebook with File -> Download .ipynb, open the notebook locally, and then File -> Download as -> PDF via LaTeX), and then submit this pdf for review.
#
# ### Let's get started!
#
# We'll start by running some imports, and loading the dataset. For this project you are free to make further imports throughout the notebook as you wish.

# %%
import tensorflow as tf
from scipy.io import loadmat
import glob

# %% [markdown]
# For the capstone project, you will use the [SVHN dataset](http://ufldl.stanford.edu/housenumbers/). This is an image dataset of over 600,000 digit images in all, and is a harder dataset than MNIST as the numbers appear in the context of natural scene images. SVHN is obtained from house numbers in Google Street View images.
#
# * Y. Netzer, T. Wang, A. Coates, A. Bissacco, B. Wu and A. Y. Ng. "Reading Digits in Natural Images with Unsupervised Feature Learning". NIPS Workshop on Deep Learning and Unsupervised Feature Learning, 2011.
#
# The train and test datasets required for this project can be downloaded from [here](http://ufldl.stanford.edu/housenumbers/train.tar.gz) and [here](http://ufldl.stanford.edu/housenumbers/test.tar.gz). Once unzipped, you will have two files: `train_32x32.mat` and `test_32x32.mat`. You should store these files in Drive for use in this Colab notebook.
#
# Your goal is to develop an end-to-end workflow for building, training, validating, evaluating and saving a neural network that classifies a real-world image into one of ten classes.

# %%
# Run this cell to connect to your Drive folder

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import matplotlib.image as mpimg
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # accessing directory structure
import cv2
import random

# %%
# Load the dataset from your Drive folder
# !pip install -q kaggle
from google.colab import files 
files.upload()
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# train = loadmat('path/to/train_32x32.mat')
# test = loadmat('path/to/test_32x32.mat')
# Out:
#      <input type="file" id="files-79ca8f6b-f799-4ba0-89ef-6022e24ba77a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-79ca8f6b-f799-4ba0-89ef-6022e24ba77a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !kaggle datasets download -d stanfordu/street-view-house-numbers
# !mkdir data
# !unzip street-view-house-numbers.zip -d data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/train/train/550.png
#   inflating: data/train/train/5500.png
#   inflating: data/train/train/5501.png
#   inflating: data/train/train/5502.png
#   inflating: data/train/train/5503.png
#   inflating: data/train/train/5504.png
#   inflating: data/train/train/5505.png
#   inflating: data/train/train/5506.png
#   inflating: data/train/train/5507.png
#   inflating: data/train/train/5508.png
#   inflating: data/train/train/5509.png
#   inflating: data/train/train/551.png
#   inflating: data/train/train/5510.png
#   inflating: data/train/train/5511.png
#   inflating: data/train/train/5512.png
#   inflating: data/train/train/5513.png
#   inflating: data/train/train/5514.png
#   inflating: data/train/train/6251.png
#   inflating: data/train/train/6252.png
#   inflating: data/train/train/6253.png
#   inflating: data/train/train/6254.png
#   inflating: data/train/train/6255.png
#   inflating: data/train/train/6256.png
#   inflating: data/train/train/6257.png
#   inflating: data/train/train/6258.png
#   inflating: data/train/train/6259.png
#   inflating: data/train/train/626.png
#   inflating: data/train/train/6260.png
#   inflating: data/train/train/6261.png
#   inflating: data/train/train/6262.png
#   inflating: data/train/train/6263.png
#   inflating: data/train/train/6264.png
#   inflating: data/train/train/6265.png
#   inflating: data/train/train/6266.png
#   inflating: data/train/train/6267.png
#   inflating: data/train/train/6268.png
#   inflating: data/train/train/6269.png
#   inflating: data/train/train/627.png
#   inflating: data/train/train/6270.png
#   inflating: data/train/train/6271.png
#   inflating: data/train/train/6272.png
#   inflating: data/train/train/6273.png
#   inflating: data/train/train/6274.png
#   inflating: data/train/train/6275.png
#   inflating: data/train/train/6276.png
#   inflating: data/train/train/6277.png
#   inflating: data/train/train/6278.png
#   inflating: data/train/train/6279.png
#   inflating: data/train/train/628.png
#   inflating: data/train/train/6280.png
#   inflating: data/train/train/6281.png
#   inflating: data/train/train/6282.png
#   inflating: data/train/train/6283.png
#   inflating: data/train/train/6284.png
#   inflating: data/train/train/6285.png
#   inflating: data/train/train/6286.png
#   inflating: data/train/train/6287.png
#   inflating: data/train/train/6288.png
#   inflating: data/train/train/6289.png
#   inflating: data/train/train/629.png
#   inflating: data/train/train/6290.png
#   inflating: data/train/train/6291.png
#   inflating: data/train/train/6292.png
#   inflating: data/train/train/6293.png
#   inflating: data/train/train/6294.png
#   inflating: data/train/train/6295.png
#   inflating: data/train/train/6296.png
#   inflating: data/train/train/6297.png
#   inflating: data/train/train/6298.png
#   inflating: data/train/train/6299.png
#   inflating: data/train/train/63.png
#   inflating: data/train/train/630.png
#   inflating: data/train/train/6300.png
#   inflating: data/train/train/6301.png
#   inflating: data/train/train/6302.png
#   inflating: data/train/train/6303.png
#   inflating: data/train/train/6304.png
#   inflating: data/train/train/6305.png
#   inflating: data/train/train/6306.png
#   inflating: data/train/train/6307.png
#   inflating: data/train/train/6308.png
#   inflating: data/train/train/6309.png
#   inflating: data/train/train/631.png
#   inflating: data/train/train/6310.png
#   inflating: data/train/train/6311.png
#   inflating: data/train/train/6312.png
#   inflating: data/train/train/6313.png
#   inflating: data/train/train/6314.png
#   inflating: data/train/train/6315.png
#   inflating: data/train/train/6316.png
#   inflating: data/train/train/6317.png
#   inflating: data/train/train/6318.png
#   inflating: data/train/train/6319.png
#   inflating: data/train/train/632.png
#   inflating: data/train/train/6320.png
#   inflating: data/train/train/6321.png
#   inflating: data/train/train/6322.png
#   inflating: data/train/train/6323.png
#   inflating: data/train/train/6324.png
#   inflating: data/train/train/6325.png
#   inflating: data/train/train/6326.png
#   inflating: data/train/train/6327.png
#   inflating: data/train/train/6328.png
#   inflating: data/train/train/6329.png
#   inflating: data/train/train/633.png
#   inflating: data/train/train/6330.png
#   inflating: data/train/train/6331.png
#   inflating: data/train/train/6332.png
#   inflating: data/train/train/6333.png
#   inflating: data/train/train/6334.png
#   inflating: data/train/train/6335.png
#   inflating: data/train/train/6336.png
#   inflating: data/train/train/6337.png
#   inflating: data/train/train/6338.png
#   inflating: data/train/train/6339.png
#   inflating: data/train/train/634.png
#   inflating: data/train/train/6340.png
#   inflating: data/train/train/6341.png
#   inflating: data/train/train/6342.png
#   inflating: data/train/train/6343.png
#   inflating: data/train/train/6344.png
#   inflating: data/train/train/6345.png
#   inflating: data/train/train/6346.png
#   inflating: data/train/train/6347.png
#   inflating: data/train/train/6348.png
#   inflating: data/train/train/6349.png
#   inflating: data/train/train/635.png
#   inflating: data/train/train/6350.png
#   inflating: data/train/train/6351.png
#   inflating: data/train/train/6352.png
#   inflating: data/train/train/6353.png
#   inflating: data/train/train/6354.png
#   inflating: data/train/train/6355.png
#   inflating: data/train/train/6356.png
#   inflating: data/train/train/6357.png
#   inflating: data/train/train/6358.png
#   inflating: data/train/train/6359.png
#   inflating: data/train/train/636.png
#   inflating: data/train/train/6360.png
#   inflating: data/train/train/6361.png
#   inflating: data/train/train/6362.png
#   inflating: data/train/train/6363.png
#   inflating: data/train/train/6364.png
#   inflating: data/train/train/6365.png
#   inflating: data/train/train/6366.png
#   inflating: data/train/train/6367.png
#   inflating: data/train/train/6368.png
#   inflating: data/train/train/6369.png
#   inflating: data/train/train/637.png
#   inflating: data/train/train/6370.png
#   inflating: data/train/train/6371.png
#   inflating: data/train/train/6372.png
#   inflating: data/train/train/6373.png
#   inflating: data/train/train/6374.png
#   inflating: data/train/train/6375.png
#   inflating: data/train/train/6376.png
#   inflating: data/train/train/6377.png
#   inflating: data/train/train/6378.png
#   inflating: data/train/train/6379.png
#   inflating: data/train/train/638.png
#   inflating: data/train/train/6380.png
#   inflating: data/train/train/6381.png
#   inflating: data/train/train/6382.png
#   inflating: data/train/train/6383.png
#   inflating: data/train/train/6384.png
#   inflating: data/train/train/6385.png
#   inflating: data/train/train/6386.png
#   inflating: data/train/train/6387.png
#   inflating: data/train/train/6388.png
#   inflating: data/train/train/6389.png
#   inflating: data/train/train/639.png
#   inflating: data/train/train/6390.png
#   inflating: data/train/train/6391.png
#   inflating: data/train/train/6392.png
#   inflating: data/train/train/6393.png
#   inflating: data/train/train/6394.png
#   inflating: data/train/train/6395.png
#   inflating: data/train/train/6396.png
#   inflating: data/train/train/6397.png
#   inflating: data/train/train/6398.png
#   inflating: data/train/train/6399.png
#   inflating: data/train/train/64.png
#   inflating: data/train/train/640.png
#   inflating: data/train/train/6400.png
#   inflating: data/train/train/6401.png
#   inflating: data/train/train/6402.png
#   inflating: data/train/train/6403.png
#   inflating: data/train/train/6404.png
#   inflating: data/train/train/6405.png
#   inflating: data/train/train/6406.png
#   inflating: data/train/train/6407.png
#   inflating: data/train/train/6408.png
#   inflating: data/train/train/6409.png
#   inflating: data/train/train/641.png
#   inflating: data/train/train/6410.png
#   inflating: data/train/train/6411.png
#   inflating: data/train/train/6412.png
#   inflating: data/train/train/6413.png
#   inflating: data/train/train/6414.png
#   inflating: data/train/train/6415.png
#   inflating: data/train/train/6416.png
#   inflating: data/train/train/6417.png
#   inflating: data/train/train/6418.png
#   inflating: data/train/train/6419.png
#   inflating: data/train/train/642.png
#   inflating: data/train/train/6420.png
#   inflating: data/train/train/6421.png
#   inflating: data/train/train/6422.png
#   inflating: data/train/train/6423.png
#   inflating: data/train/train/6424.png
#   inflating: data/train/train/6425.png
#   inflating: data/train/train/6426.png
#   inflating: data/train/train/6427.png
#   inflating: data/train/train/6428.png
#   inflating: data/train/train/6429.png
#   inflating: data/train/train/643.png
#   inflating: data/train/train/6430.png
#   inflating: data/train/train/6431.png
#   inflating: data/train/train/6432.png
#   inflating: data/train/train/6433.png
#   inflating: data/train/train/6434.png
#   inflating: data/train/train/6435.png
#   inflating: data/train/train/6436.png
#   inflating: data/train/train/6437.png
#   inflating: data/train/train/6438.png
#   inflating: data/train/train/6439.png
#   inflating: data/train/train/644.png
#   inflating: data/train/train/6440.png
#   inflating: data/train/train/6441.png
#   inflating: data/train/train/6442.png
#   inflating: data/train/train/6443.png
#   inflating: data/train/train/6444.png
#   inflating: data/train/train/6445.png
#   inflating: data/train/train/6446.png
#   inflating: data/train/train/6447.png
#   inflating: data/train/train/6448.png
#   inflating: data/train/train/6449.png
#   inflating: data/train/train/645.png
#   inflating: data/train/train/6450.png
#   inflating: data/train/train/6451.png
#   inflating: data/train/train/6452.png
#   inflating: data/train/train/6453.png
#   inflating: data/train/train/6454.png
#   inflating: data/train/train/6455.png
#   inflating: data/train/train/6456.png
#   inflating: data/train/train/6457.png
#   inflating: data/train/train/6458.png
#   inflating: data/train/train/6459.png
#   inflating: data/train/train/646.png
#   inflating: data/train/train/6460.png
#   inflating: data/train/train/6461.png
#   inflating: data/train/train/6462.png
#   inflating: data/train/train/6463.png
#   inflating: data/train/train/6464.png
#   inflating: data/train/train/6465.png
#   inflating: data/train/train/6466.png
#   inflating: data/train/train/6467.png
#   inflating: data/train/train/6468.png
#   inflating: data/train/train/6469.png
#   inflating: data/train/train/647.png
#   inflating: data/train/train/6470.png
#   inflating: data/train/train/6471.png
#   inflating: data/train/train/6472.png
#   inflating: data/train/train/6473.png
#   inflating: data/train/train/6474.png
#   inflating: data/train/train/6475.png
#   inflating: data/train/train/6476.png
#   inflating: data/train/train/6477.png
#   inflating: data/train/train/6478.png
#   inflating: data/train/train/6479.png
#   inflating: data/train/train/648.png
#   inflating: data/train/train/6480.png
#   inflating: data/train/train/6481.png
#   inflating: data/train/train/6482.png
#   inflating: data/train/train/6483.png
#   inflating: data/train/train/6484.png
#   inflating: data/train/train/6485.png
#   inflating: data/train/train/6486.png
#   inflating: data/train/train/6487.png
#   inflating: data/train/train/6488.png
#   inflating: data/train/train/6489.png
#   inflating: data/train/train/649.png
#   inflating: data/train/train/6490.png
#   inflating: data/train/train/6491.png
#   inflating: data/train/train/6492.png
#   inflating: data/train/train/6493.png
#   inflating: data/train/train/6494.png
#   inflating: data/train/train/6495.png
#   inflating: data/train/train/6496.png
#   inflating: data/train/train/6497.png
#   inflating: data/train/train/6498.png
#   inflating: data/train/train/6499.png
#   inflating: data/train/train/65.png
#   inflating: data/train/train/650.png
#   inflating: data/train/train/6500.png
#   inflating: data/train/train/6501.png
#   inflating: data/train/train/6502.png
#   inflating: data/train/train/6503.png
#   inflating: data/train/train/6504.png
#   inflating: data/train/train/6505.png
#   inflating: data/train/train/6506.png
#   inflating: data/train/train/6507.png
#   inflating: data/train/train/6508.png
#   inflating: data/train/train/6509.png
#   inflating: data/train/train/651.png
#   inflating: data/train/train/6510.png
#   inflating: data/train/train/6511.png
#   inflating: data/train/train/6512.png
#   inflating: data/train/train/6513.png
#   inflating: data/train/train/6514.png
#   inflating: data/train/train/6515.png
#   inflating: data/train/train/6516.png
#   inflating: data/train/train/6517.png
#   inflating: data/train/train/6518.png
#   inflating: data/train/train/6519.png
#   inflating: data/train/train/652.png
#   inflating: data/train/train/6520.png
#   inflating: data/train/train/6521.png
#   inflating: data/train/train/6522.png
#   inflating: data/train/train/6523.png
#   inflating: data/train/train/6524.png
#   inflating: data/train/train/6525.png
#   inflating: data/train/train/6526.png
#   inflating: data/train/train/6527.png
#   inflating: data/train/train/6528.png
#   inflating: data/train/train/6529.png
#   inflating: data/train/train/653.png
#   inflating: data/train/train/6530.png
#   inflating: data/train/train/6531.png
#   inflating: data/train/train/6532.png
#   inflating: data/train/train/6533.png
#   inflating: data/train/train/6534.png
#   inflating: data/train/train/6535.png
#   inflating: data/train/train/6536.png
#   inflating: data/train/train/6537.png
#   inflating: data/train/train/6538.png
#   inflating: data/train/train/6539.png
#   inflating: data/train/train/654.png
#   inflating: data/train/train/6540.png
#   inflating: data/train/train/6541.png
#   inflating: data/train/train/6542.png
#   inflating: data/train/train/6543.png
#   inflating: data/train/train/6544.png
#   inflating: data/train/train/6545.png
#   inflating: data/train/train/6546.png
#   inflating: data/train/train/6547.png
#   inflating: data/train/train/6548.png
#   inflating: data/train/train/6549.png
#   inflating: data/train/train/655.png
#   inflating: data/train/train/6550.png
#   inflating: data/train/train/6551.png
#   inflating: data/train/train/6552.png
#   inflating: data/train/train/6553.png
#   inflating: data/train/train/6554.png
# ...
#   inflating: data/train/train/9649.png
#   inflating: data/train/train/965.png
#   inflating: data/train/train/9650.png
#   inflating: data/train/train/9651.png
#   inflating: data/train/train/9652.png
#   inflating: data/train/train/9653.png
#   inflating: data/train/train/9654.png
#   inflating: data/train/train/9655.png
#   inflating: data/train/train/9656.png
#   inflating: data/train/train/9657.png
#   inflating: data/train/train/9658.png
#   inflating: data/train/train/9659.png
#   inflating: data/train/train/966.png
#   inflating: data/train/train/9660.png
#   inflating: data/train/train/9661.png
#   inflating: data/train/train/9662.png
#   inflating: data/train/train/9663.png
#   inflating: data/train/train/9664.png
#   inflating: data/train/train/9665.png
#   inflating: data/train/train/9666.png
#   inflating: data/train/train/9667.png
#   inflating: data/train/train/9668.png
#   inflating: data/train/train/9669.png
#   inflating: data/train/train/967.png
#   inflating: data/train/train/9670.png
#   inflating: data/train/train/9671.png
#   inflating: data/train/train/9672.png
#   inflating: data/train/train/9673.png
#   inflating: data/train/train/9674.png
#   inflating: data/train/train/9675.png
#   inflating: data/train/train/9676.png
#   inflating: data/train/train/9677.png
#   inflating: data/train/train/9678.png
#   inflating: data/train/train/9679.png
#   inflating: data/train/train/968.png
#   inflating: data/train/train/9680.png
#   inflating: data/train/train/9681.png
#   inflating: data/train/train/9682.png
#   inflating: data/train/train/9683.png
#   inflating: data/train/train/9684.png
#   inflating: data/train/train/9685.png
#   inflating: data/train/train/9686.png
#   inflating: data/train/train/9687.png
#   inflating: data/train/train/9688.png
#   inflating: data/train/train/9689.png
#   inflating: data/train/train/969.png
#   inflating: data/train/train/9690.png
#   inflating: data/train/train/9691.png
#   inflating: data/train/train/9692.png
#   inflating: data/train/train/9693.png
#   inflating: data/train/train/9694.png
#   inflating: data/train/train/9695.png
#   inflating: data/train/train/9696.png
#   inflating: data/train/train/9697.png
#   inflating: data/train/train/9698.png
#   inflating: data/train/train/9699.png
#   inflating: data/train/train/97.png
#   inflating: data/train/train/970.png
#   inflating: data/train/train/9700.png
#   inflating: data/train/train/9701.png
#   inflating: data/train/train/9702.png
#   inflating: data/train/train/9703.png
#   inflating: data/train/train/9704.png
#   inflating: data/train/train/9705.png
#   inflating: data/train/train/9706.png
#   inflating: data/train/train/9707.png
#   inflating: data/train/train/9708.png
#   inflating: data/train/train/9709.png
#   inflating: data/train/train/971.png
#   inflating: data/train/train/9710.png
#   inflating: data/train/train/9711.png
#   inflating: data/train/train/9712.png
#   inflating: data/train/train/9713.png
#   inflating: data/train/train/9714.png
#   inflating: data/train/train/9715.png
#   inflating: data/train/train/9716.png
#   inflating: data/train/train/9717.png
#   inflating: data/train/train/9718.png
#   inflating: data/train/train/9719.png
#   inflating: data/train/train/972.png
#   inflating: data/train/train/9720.png
#   inflating: data/train/train/9721.png
#   inflating: data/train/train/9722.png
#   inflating: data/train/train/9723.png
#   inflating: data/train/train/9724.png
#   inflating: data/train/train/9725.png
#   inflating: data/train/train/9726.png
#   inflating: data/train/train/9727.png
#   inflating: data/train/train/9728.png
#   inflating: data/train/train/9729.png
#   inflating: data/train/train/973.png
#   inflating: data/train/train/9730.png
#   inflating: data/train/train/9731.png
#   inflating: data/train/train/9732.png
#   inflating: data/train/train/9733.png
#   inflating: data/train/train/9734.png
#   inflating: data/train/train/9735.png
#   inflating: data/train/train/9736.png
#   inflating: data/train/train/9737.png
#   inflating: data/train/train/9738.png
#   inflating: data/train/train/9739.png
#   inflating: data/train/train/974.png
#   inflating: data/train/train/9740.png
#   inflating: data/train/train/9741.png
#   inflating: data/train/train/9742.png
#   inflating: data/train/train/9743.png
#   inflating: data/train/train/9744.png
#   inflating: data/train/train/9745.png
#   inflating: data/train/train/9746.png
#   inflating: data/train/train/9747.png
#   inflating: data/train/train/9748.png
#   inflating: data/train/train/9749.png
#   inflating: data/train/train/975.png
#   inflating: data/train/train/9750.png
#   inflating: data/train/train/9751.png
#   inflating: data/train/train/9752.png
#   inflating: data/train/train/9753.png
#   inflating: data/train/train/9754.png
#   inflating: data/train/train/9755.png
#   inflating: data/train/train/9756.png
#   inflating: data/train/train/9757.png
#   inflating: data/train/train/9758.png
#   inflating: data/train/train/9759.png
#   inflating: data/train/train/976.png
#   inflating: data/train/train/9760.png
#   inflating: data/train/train/9761.png
#   inflating: data/train/train/9762.png
#   inflating: data/train/train/9763.png
#   inflating: data/train/train/9764.png
#   inflating: data/train/train/9765.png
#   inflating: data/train/train/9766.png
#   inflating: data/train/train/9767.png
#   inflating: data/train/train/9768.png
#   inflating: data/train/train/9769.png
#   inflating: data/train/train/977.png
#   inflating: data/train/train/9770.png
#   inflating: data/train/train/9771.png
#   inflating: data/train/train/9772.png
#   inflating: data/train/train/9773.png
#   inflating: data/train/train/9774.png
#   inflating: data/train/train/9775.png
#   inflating: data/train/train/9776.png
#   inflating: data/train/train/9777.png
#   inflating: data/train/train/9778.png
#   inflating: data/train/train/9779.png
#   inflating: data/train/train/978.png
#   inflating: data/train/train/9780.png
#   inflating: data/train/train/9781.png
#   inflating: data/train/train/9782.png
#   inflating: data/train/train/9783.png
#   inflating: data/train/train/9784.png
#   inflating: data/train/train/9785.png
#   inflating: data/train/train/9786.png
#   inflating: data/train/train/9787.png
#   inflating: data/train/train/9788.png
#   inflating: data/train/train/9789.png
#   inflating: data/train/train/979.png
#   inflating: data/train/train/9790.png
#   inflating: data/train/train/9791.png
#   inflating: data/train/train/9792.png
#   inflating: data/train/train/9793.png
#   inflating: data/train/train/9794.png
#   inflating: data/train/train/9795.png
#   inflating: data/train/train/9796.png
#   inflating: data/train/train/9797.png
#   inflating: data/train/train/9798.png
#   inflating: data/train/train/9799.png
#   inflating: data/train/train/98.png
#   inflating: data/train/train/980.png
#   inflating: data/train/train/9800.png
#   inflating: data/train/train/9801.png
#   inflating: data/train/train/9802.png
#   inflating: data/train/train/9803.png
#   inflating: data/train/train/9804.png
#   inflating: data/train/train/9805.png
#   inflating: data/train/train/9806.png
#   inflating: data/train/train/9807.png
#   inflating: data/train/train/9808.png
#   inflating: data/train/train/9809.png
#   inflating: data/train/train/981.png
#   inflating: data/train/train/9810.png
#   inflating: data/train/train/9811.png
#   inflating: data/train/train/9812.png
#   inflating: data/train/train/9813.png
#   inflating: data/train/train/9814.png
#   inflating: data/train/train/9815.png
#   inflating: data/train/train/9816.png
#   inflating: data/train/train/9817.png
#   inflating: data/train/train/9818.png
#   inflating: data/train/train/9819.png
#   inflating: data/train/train/982.png
#   inflating: data/train/train/9820.png
#   inflating: data/train/train/9821.png
#   inflating: data/train/train/9822.png
#   inflating: data/train/train/9823.png
#   inflating: data/train/train/9824.png
#   inflating: data/train/train/9825.png
#   inflating: data/train/train/9826.png
#   inflating: data/train/train/9827.png
#   inflating: data/train/train/9828.png
#   inflating: data/train/train/9829.png
#   inflating: data/train/train/983.png
#   inflating: data/train/train/9830.png
#   inflating: data/train/train/9831.png
#   inflating: data/train/train/9832.png
#   inflating: data/train/train/9833.png
#   inflating: data/train/train/9834.png
#   inflating: data/train/train/9835.png
#   inflating: data/train/train/9836.png
#   inflating: data/train/train/9837.png
#   inflating: data/train/train/9838.png
#   inflating: data/train/train/9839.png
#   inflating: data/train/train/984.png
#   inflating: data/train/train/9840.png
#   inflating: data/train/train/9841.png
#   inflating: data/train/train/9842.png
#   inflating: data/train/train/9843.png
#   inflating: data/train/train/9844.png
#   inflating: data/train/train/9845.png
#   inflating: data/train/train/9846.png
#   inflating: data/train/train/9847.png
#   inflating: data/train/train/9848.png
#   inflating: data/train/train/9849.png
#   inflating: data/train/train/985.png
#   inflating: data/train/train/9850.png
#   inflating: data/train/train/9851.png
#   inflating: data/train/train/9852.png
#   inflating: data/train/train/9853.png
#   inflating: data/train/train/9854.png
#   inflating: data/train/train/9855.png
#   inflating: data/train/train/9856.png
#   inflating: data/train/train/9857.png
#   inflating: data/train/train/9858.png
#   inflating: data/train/train/9859.png
#   inflating: data/train/train/986.png
#   inflating: data/train/train/9860.png
#   inflating: data/train/train/9861.png
#   inflating: data/train/train/9862.png
#   inflating: data/train/train/9863.png
#   inflating: data/train/train/9864.png
#   inflating: data/train/train/9865.png
#   inflating: data/train/train/9866.png
#   inflating: data/train/train/9867.png
#   inflating: data/train/train/9868.png
#   inflating: data/train/train/9869.png
#   inflating: data/train/train/987.png
#   inflating: data/train/train/9870.png
#   inflating: data/train/train/9871.png
#   inflating: data/train/train/9872.png
#   inflating: data/train/train/9873.png
#   inflating: data/train/train/9874.png
#   inflating: data/train/train/9875.png
#   inflating: data/train/train/9876.png
#   inflating: data/train/train/9877.png
#   inflating: data/train/train/9878.png
#   inflating: data/train/train/9879.png
#   inflating: data/train/train/988.png
#   inflating: data/train/train/9880.png
#   inflating: data/train/train/9881.png
#   inflating: data/train/train/9882.png
#   inflating: data/train/train/9883.png
#   inflating: data/train/train/9884.png
#   inflating: data/train/train/9885.png
#   inflating: data/train/train/9886.png
#   inflating: data/train/train/9887.png
#   inflating: data/train/train/9888.png
#   inflating: data/train/train/9889.png
#   inflating: data/train/train/989.png
#   inflating: data/train/train/9890.png
#   inflating: data/train/train/9891.png
#   inflating: data/train/train/9892.png
#   inflating: data/train/train/9893.png
#   inflating: data/train/train/9894.png
#   inflating: data/train/train/9895.png
#   inflating: data/train/train/9896.png
#   inflating: data/train/train/9897.png
#   inflating: data/train/train/9898.png
#   inflating: data/train/train/9899.png
#   inflating: data/train/train/99.png
#   inflating: data/train/train/990.png
#   inflating: data/train/train/9900.png
#   inflating: data/train/train/9901.png
#   inflating: data/train/train/9902.png
#   inflating: data/train/train/9903.png
#   inflating: data/train/train/9904.png
#   inflating: data/train/train/9905.png
#   inflating: data/train/train/9906.png
#   inflating: data/train/train/9907.png
#   inflating: data/train/train/9908.png
#   inflating: data/train/train/9909.png
#   inflating: data/train/train/991.png
#   inflating: data/train/train/9910.png
#   inflating: data/train/train/9911.png
#   inflating: data/train/train/9912.png
#   inflating: data/train/train/9913.png
#   inflating: data/train/train/9914.png
#   inflating: data/train/train/9915.png
#   inflating: data/train/train/9916.png
#   inflating: data/train/train/9917.png
#   inflating: data/train/train/9918.png
#   inflating: data/train/train/9919.png
#   inflating: data/train/train/992.png
#   inflating: data/train/train/9920.png
#   inflating: data/train/train/9921.png
#   inflating: data/train/train/9922.png
#   inflating: data/train/train/9923.png
#   inflating: data/train/train/9924.png
#   inflating: data/train/train/9925.png
#   inflating: data/train/train/9926.png
#   inflating: data/train/train/9927.png
#   inflating: data/train/train/9928.png
#   inflating: data/train/train/9929.png
#   inflating: data/train/train/993.png
#   inflating: data/train/train/9930.png
#   inflating: data/train/train/9931.png
#   inflating: data/train/train/9932.png
#   inflating: data/train/train/9933.png
#   inflating: data/train/train/9934.png
#   inflating: data/train/train/9935.png
#   inflating: data/train/train/9936.png
#   inflating: data/train/train/9937.png
#   inflating: data/train/train/9938.png
#   inflating: data/train/train/9939.png
#   inflating: data/train/train/994.png
#   inflating: data/train/train/9940.png
#   inflating: data/train/train/9941.png
#   inflating: data/train/train/9942.png
#   inflating: data/train/train/9943.png
#   inflating: data/train/train/9944.png
#   inflating: data/train/train/9945.png
#   inflating: data/train/train/9946.png
#   inflating: data/train/train/9947.png
#   inflating: data/train/train/9948.png
#   inflating: data/train/train/9949.png
#   inflating: data/train/train/995.png
#   inflating: data/train/train/9950.png
#   inflating: data/train/train/9951.png
#   inflating: data/train/train/9952.png
#   inflating: data/train/train/9953.png
#   inflating: data/train/train/9954.png
#   inflating: data/train/train/9955.png
#   inflating: data/train/train/9956.png
#   inflating: data/train/train/9957.png
#   inflating: data/train/train/9958.png
#   inflating: data/train/train/9959.png
#   inflating: data/train/train/996.png
#   inflating: data/train/train/9960.png
#   inflating: data/train/train/9961.png
#   inflating: data/train/train/9962.png
#   inflating: data/train/train/9963.png
#   inflating: data/train/train/9964.png
#   inflating: data/train/train/9965.png
#   inflating: data/train/train/9966.png
#   inflating: data/train/train/9967.png
#   inflating: data/train/train/9968.png
#   inflating: data/train/train/9969.png
#   inflating: data/train/train/997.png
#   inflating: data/train/train/9970.png
#   inflating: data/train/train/9971.png
#   inflating: data/train/train/9972.png
#   inflating: data/train/train/9973.png
#   inflating: data/train/train/9974.png
#   inflating: data/train/train/9975.png
#   inflating: data/train/train/9976.png
#   inflating: data/train/train/9977.png
#   inflating: data/train/train/9978.png
#   inflating: data/train/train/9979.png
#   inflating: data/train/train/998.png
#   inflating: data/train/train/9980.png
#   inflating: data/train/train/9981.png
#   inflating: data/train/train/9982.png
#   inflating: data/train/train/9983.png
#   inflating: data/train/train/9984.png
#   inflating: data/train/train/9985.png
#   inflating: data/train/train/9986.png
#   inflating: data/train/train/9987.png
#   inflating: data/train/train/9988.png
#   inflating: data/train/train/9989.png
#   inflating: data/train/train/999.png
#   inflating: data/train/train/9990.png
#   inflating: data/train/train/9991.png
#   inflating: data/train/train/9992.png
#   inflating: data/train/train/9993.png
#   inflating: data/train/train/9994.png
#   inflating: data/train/train/9995.png
#   inflating: data/train/train/9996.png
#   inflating: data/train/train/9997.png
#   inflating: data/train/train/9998.png
#   inflating: data/train/train/9999.png
#   inflating: data/train/train/see_bboxes.m
#   inflating: data/train_digitStruct.mat

# %% [markdown]
# Both `train` and `test` are dictionaries with keys `X` and `y` for the input images and labels respectively.

# %% [markdown]
# ## 1. Inspect and preprocess the dataset
# * Extract the training and testing images and labels separately from the train and test dictionaries loaded for you.
# * Select a random sample of images and corresponding labels from the dataset (at least 10), and display them in a figure.
# * Convert the training and test images to grayscale by taking the average across all colour channels for each pixel. _Hint: retain the channel dimension, which will now have size 1._
# * Select a random sample of the grayscale images and corresponding labels from the dataset (at least 10), and display them in a figure.

# %%
train_data=os.path.join('/content/data/train/train/')

# %%
train_label=pd.read_csv('/content/data/train_digitStruct.mat')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-88-2f16612a3815> in <module>()
# ----> 1 train_label=pd.read_csv('/content/data/train_digitStruct.mat')
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     458
#     459     try:
# --> 460         data = parser.read(nrows)
#     461     finally:
#     462         parser.close()
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read(self, nrows)
#    1196     def read(self, nrows=None):
#    1197         nrows = _validate_integer("nrows", nrows)
# -> 1198         ret = self._engine.read(nrows)
#    1199
#    1200         # May alter columns / col_dict
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read(self, nrows)
#    2155     def read(self, nrows=None):
#    2156         try:
# -> 2157             data = self._reader.read(nrows)
#    2158         except StopIteration:
#    2159             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Buffer overflow caught - possible malformed input file.

# %%
test_data=os.path.join('/content/data/test/test/')

# %%
print(os.listdir(train_data))
# Out:
# ['21226.png', '15935.png', '24497.png', '9266.png', '23382.png', '4485.png', '7594.png', '9715.png', '26355.png', '11292.png', '18416.png', '21440.png', '13352.png', '4420.png', '23561.png', '17805.png', '3146.png', '8256.png', '3995.png', '7292.png', '28991.png', '17445.png', '5557.png', '27944.png', '10863.png', '23496.png', '11233.png', '3084.png', '31686.png', '22562.png', '13948.png', '32191.png', '20253.png', '7511.png', '28801.png', '7979.png', '2591.png', '31267.png', '28923.png', '11877.png', '1865.png', '25986.png', '22892.png', '16303.png', '33276.png', '1359.png', '18576.png', '24455.png', '23166.png', '8415.png', '182.png', '14590.png', '14288.png', '27098.png', '2592.png', '836.png', '24963.png', '5418.png', '6985.png', '23217.png', '3645.png', '29037.png', '5001.png', '22119.png', '15368.png', '20668.png', '21617.png', '6324.png', '3372.png', '24919.png', '1319.png', '3943.png', '22527.png', '23687.png', '17734.png', '6090.png', '14259.png', '10781.png', '21495.png', '29859.png', '21847.png', '5678.png', '17858.png', '27495.png', '7008.png', '584.png', '15701.png', '21662.png', '33015.png', '23291.png', '4499.png', '25710.png', '7702.png', '26979.png', '18178.png', '14435.png', '15068.png', '28996.png', '10719.png', '28172.png', '704.png', '3833.png', '26750.png', '31728.png', '10975.png', '7288.png', '24916.png', '21272.png', '24152.png', '3315.png', '13787.png', '837.png', '20890.png', '13743.png', '16198.png', '30281.png', '16070.png', '22980.png', '30529.png', '25424.png', '21726.png', '19349.png', '10051.png', '5208.png', '2694.png', '32891.png', '1140.png', '16311.png', '24110.png', '24221.png', '10937.png', '16678.png', '2059.png', '8446.png', '27981.png', '11184.png', '8670.png', '33354.png', '12574.png', '26005.png', '9250.png', '11217.png', '20814.png', '2526.png', '28875.png', '29416.png', '21308.png', '24649.png', '30321.png', '14503.png', '21048.png', '7127.png', '13221.png', '25616.png', '24850.png', '14602.png', '28076.png', '5364.png', '4257.png', '12379.png', '16326.png', '18197.png', '28129.png', '12655.png', '19814.png', '26858.png', '32126.png', '7848.png', '19062.png', '20443.png', '22434.png', '11334.png', '25121.png', '18712.png', '8071.png', '7617.png', '2388.png', '25973.png', '7737.png', '3155.png', '27116.png', '170.png', '19824.png', '26743.png', '30430.png', '11663.png', '12956.png', '27655.png', '33161.png', '15802.png', '14148.png', '32403.png', '6487.png', '23735.png', '27278.png', '15231.png', '11471.png', '17915.png', '4840.png', '11288.png', '25098.png', '4696.png', '16478.png', '28372.png', '25929.png', '878.png', '1490.png', '32299.png', '12227.png', '19161.png', '27872.png', '6259.png', '21228.png', '29306.png', '16280.png', '24552.png', '24318.png', '5704.png', '13334.png', '1745.png', '10262.png', '6460.png', '16351.png', '28273.png', '9515.png', '15105.png', '16069.png', '941.png', '10128.png', '18020.png', '7794.png', '29584.png', '1543.png', '20466.png', '880.png', '9069.png', '20735.png', '14195.png', '16164.png', '32547.png', '20162.png', '5349.png', '31923.png', '27599.png', '26368.png', '32138.png', '32082.png', '12631.png', '879.png', '11318.png', '17629.png', '17298.png', '5635.png', '33030.png', '19600.png', '18459.png', '19728.png', '7465.png', '19952.png', '16443.png', '21388.png', '8609.png', '3481.png', '20454.png', '12067.png', '28729.png', '6076.png', '30988.png', '19912.png', '31937.png', '15839.png', '11694.png', '33346.png', '15463.png', '21613.png', '27683.png', '27453.png', '23543.png', '5797.png', '32200.png', '22651.png', '30071.png', '16904.png', '17903.png', '25028.png', '27033.png', '2069.png', '22550.png', '18666.png', '32591.png', '4483.png', '11095.png', '22148.png', '32750.png', '29058.png', '31454.png', '29174.png', '32639.png', '20450.png', '11639.png', '20742.png', '9060.png', '7967.png', '9684.png', '13949.png', '28904.png', '26440.png', '26712.png', '27101.png', '28660.png', '6586.png', '33279.png', '7351.png', '31383.png', '18921.png', ' ...

# %%
Files = glob.glob("/content/data/train/train/*.png")
for f in Files[:11]:
  img=cv2.imread(f)
  plt.imshow(img)
  plt.axis('off')

# %%
def load_image(path):
  for f in random.sample(glob.glob("/content/data/train/train/*.png"), 10):
    plt.figure(figsize=(5,5))
    d=random.choice(files)
    img=cv2.imread(d)
    plt.imshow(img)
    plt.axis('off')

# %%
load_image('/content/data/train/train/')

# %%
def load_image(path):
  for files in os.path.join():
    image=cv2.imread(files)

# %%
load_images("/content/data/train/train/")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-b8293783ecbf> in <module>()
# ----> 1 load_images("/content/data/train/train/")
#
# <ipython-input-48-8861461c569e> in load_images(folder)
#       3     for filename in (os.path.join(folder)[0]):
#       4         img = cv2.imread(filename)
# ----> 5         images=plt.imshow(img)
#       6         if img is not None:
#       7             images.append(img)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5624                               resample=resample, **kwargs)
#    5625
# -> 5626         im.set_data(X)
#    5627         im.set_alpha(alpha)
#    5628         if im.get_clip_path() is None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in set_data(self, A)
#     692                 not np.can_cast(self._A.dtype, float, "same_kind")):
#     693             raise TypeError("Image data of dtype {} cannot be converted to "
# --> 694                             "float".format(self._A.dtype))
#     695
#     696         if not (self._A.ndim == 2
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
img1=cv2.imread('data/train/train/1.png')
plt.imshow(img1)

# %% [markdown]
# ## 2. MLP neural network classifier
# * Build an MLP classifier model using the Sequential API. Your model should use only Flatten and Dense layers, with the final layer having a 10-way softmax output.
# * You should design and build the model yourself. Feel free to experiment with different MLP architectures. _Hint: to achieve a reasonable accuracy you won't need to use more than 4 or 5 layers._
# * Print out the model summary (using the summary() method)
# * Compile and train the model (we recommend a maximum of 30 epochs), making use of both training and validation sets during the training run.
# * Your model should track at least one appropriate metric, and use at least two callbacks during training, one of which should be a ModelCheckpoint callback.
# * As a guide, you should aim to achieve a final categorical cross entropy training loss of less than 1.0 (the validation loss might be higher).
# * Plot the learning curves for loss vs epoch and accuracy vs epoch for both training and validation sets.
# * Compute and display the loss and accuracy of the trained model on the test set.

# %% [markdown]
# ## 3. CNN neural network classifier
# * Build a CNN classifier model using the Sequential API. Your model should use the Conv2D, MaxPool2D, BatchNormalization, Flatten, Dense and Dropout layers. The final layer should again have a 10-way softmax output.
# * You should design and build the model yourself. Feel free to experiment with different CNN architectures. _Hint: to achieve a reasonable accuracy you won't need to use more than 2 or 3 convolutional layers and 2 fully connected layers.)_
# * The CNN model should use fewer trainable parameters than your MLP model.
# * Compile and train the model (we recommend a maximum of 30 epochs), making use of both training and validation sets during the training run.
# * Your model should track at least one appropriate metric, and use at least two callbacks during training, one of which should be a ModelCheckpoint callback.
# * You should aim to beat the MLP model performance with fewer parameters!
# * Plot the learning curves for loss vs epoch and accuracy vs epoch for both training and validation sets.
# * Compute and display the loss and accuracy of the trained model on the test set.

# %% [markdown]
# ## 4. Get model predictions
# * Load the best weights for the MLP and CNN models that you saved during the training run.
# * Randomly select 5 images and corresponding labels from the test set and display the images with their labels.
# * Alongside the image and label, show each model’s predictive distribution as a bar chart, and the final model prediction given by the label with maximum probability.
